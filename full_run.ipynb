# %%
from plot_data import *

num_ellipses = 10
plot_data_jupyter_call([num_ellipses,])
# Out:
# Drawing  10 sample ellipses and their projections...
# ----------------------------Ellipse  0 parameters:---------------------------
# x0=0.47840350240492063 y0=0.5004735396560481 a=0.47080296008023026 b=0.4710091723286409 c=95.8809736428715
# density (64, 64) projections (136,)
# ----------------------------Ellipse  1 parameters:---------------------------
# x0=0.1312165140555604 y0=0.6073497439577249 a=0.11902322996859005 b=0.3826015190245525 c=33.18155424400688
# density (64, 64) projections (136,)
# ----------------------------Ellipse  2 parameters:---------------------------
# x0=0.5848124034747363 y0=0.6002029668636243 a=0.30253817310718356 b=0.39214298330476766 c=87.97096162009115
# density (64, 64) projections (136,)
# ----------------------------Ellipse  3 parameters:---------------------------
# x0=0.538989967118341 y0=0.5167916112079002 a=0.4419690547181299 b=0.4747229177737679 c=32.80298195728023
# density (64, 64) projections (136,)
# ...

# %%
from train_convnet_sigma_err import *

exp_dir = 'exp5'
epoch_size = 3
num_epochs = 5
train_model_jupyter_call([exp_dir, epoch_size, num_epochs])
# Out:
# Will save this model to ./exps/exp5
# experiment parameters {'dim': 136, 'no_batches_ep': 3, 'shuffle': True, 'exp_id': './exps/exp5', 'batch_size': 144, 'epoch_size': 3, 'n_splits': 2}
# Got 10000  data  samples. Hyperparameters were: f-> [ 10  75 250] x [0.125 0.175 0.225] err [0.5 1. ]
# ------------------Printing stats for main generator------------------
# f,x,err,count
# 0-0-0 174
# 0-0-1 1043
# 0-1-0 201
# 0-1-1 407
# 0-2-0 363
# 0-2-1 639
# 1-0-0 728
# 1-0-1 1015
# 1-1-0 710
# 1-1-1 1043
# 1-2-0 593
# 1-2-1 1010
# 2-0-0 318
# 2-0-1 28
# 2-1-0 649
# 2-1-1 115
# 2-2-0 644
# 2-2-1 320
# Total number of samples: 10000
# ------------------------------------Training member 1 of ensemble...--------------------------------------
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# m (InputLayer)               [(None, 136, 1)]          0
# ...
